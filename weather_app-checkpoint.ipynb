# %%
import requests

API_KEY = "5fb441d84299939cd3f02e0d0c62eed0"

city = "Mumbai"

url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

print(response.status_code)
print(response.text)
# Out:
# Enter city name:  mumbai
# Invalid API key.
