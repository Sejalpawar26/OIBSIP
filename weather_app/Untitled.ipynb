# %%
import requests

API_KEY = "PASTE_YOUR_API_KEY_HERE"

city = "Mumbai"

url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"coord":{"lon":72.8479,"lat":19.0144},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"base":"stations","main":{"temp":26.99,"feels_like":30,"temp_min":26.99,"temp_max":26.99,"pressure":1010,"humidity":83,"sea_level":1010,"grnd_level":1009},"visibility":10000,"wind":{"speed":1.54,"deg":130},"rain":{"1h":0.1},"clouds":{"all":97},"dt":1790007114,"sys":{"type":1,"id":9052,"country":"IN","sunrise":1789952235,"sunset":1789995991},"timezone":19800,"id":1275339,"name":"Mumbai","cod":200}
